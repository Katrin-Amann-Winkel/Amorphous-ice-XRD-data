# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit
from scipy import signal
from os import walk
import csv
import sys
from PIL import Image
import scipy as sc
import gdal
import math
from scipy.interpolate import interp1d
import os
import scipy

# %% [markdown]
# # Base paths

# %%
base_path = ''

# %% [markdown]
# # Parameters

# %%
iq1,iq2,iq3=106,147,162 # defines the position of lines in temp. plot (numbers itself correspond to a position in array)
it1=0
t=np.array([116.8])

# %% [markdown]
# # Load files

# %%
files = []
i=0
for (dirpath, dirnames, filenames) in walk(base_path):
    files.extend(filenames)
    break

#----S(Q)-----
q_Sq_a1_b1 = np.load(base_path+'q_Sq_OO_r2639_2693.npy')
Sq_a1_b1 = q_Sq_a1_b1[1]
q = q_Sq_a1_b1[0]

Sq_plot = np.zeros([26,len(q)])
Sq_plot[0:26] = Sq_a1_b1[6:32]         ##full length is 53 , start at files 2644 = 80 K


#----gr-----
r_gr_a1_b1 = np.load(base_path+'r_gr_OO_r2639_2693.npy')
gr_a1_b1 = r_gr_a1_b1[1]
r = r_gr_a1_b1[0]

gr_plot = np.zeros([26,len(r)])
gr_plot[0:26] = gr_a1_b1[6:32]


print Sq_plot.shape
# Out:
# (26, 2235)

# %% [markdown]
# # Temperature

# %%
T=np.array([80.4,92.2,94.5,96.6,98.7,100.4,102.4,104.5,106.2,108.1,110,112,113.9,115.7,117.7,119.6,121.4,123.4,125.3,127.2,129.1,131.1,132.9,134.7,136.6,138.6])

print T
print T.shape
# Out:
# [  80.4   92.2   94.5   96.6   98.7  100.4  102.4  104.5  106.2  108.1
#   110.   112.   113.9  115.7  117.7  119.6  121.4  123.4  125.3  127.2
#   129.1  131.1  132.9  134.7  136.6  138.6]
# (26,)

# %% [markdown]
# #  Plot fraction curve and g(r)

# %%
plt.figure()
plt.figure(figsize = (18,5))

#-----------------------------------------------
# --plot S(Q)
ax1 = plt.subplot(1,3,1)
for i in range(len(Sq_plot)):    
    color_index = float(i)/float(len(Sq_plot))
    color = plt.cm.jet(color_index)
    plt.plot(q,Sq_plot[i],alpha=0.5,color=color,label=i)
       
plt.xlabel('Q ($\mathring{A}^{-1}$)', fontsize=20)
plt.ylabel('S$_{OO}$ (Q)', fontsize=20)
plt.xlim([1,5])
plt.ylim([0,2.75])
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.text(3.8,2,'VHDA',fontsize=20)
plt.text(3.8,1.7,'(fast heating)',fontsize=14)

plt.axvline(x=q[iq1],ymin=0,ymax=10000,c="red",linewidth=1.5,linestyle='--',label = 'Q = %.2f $\mathring{A}^{-1}$'%q[iq1])
plt.axvline(x=q[iq2],ymin=0,ymax=10000,c="blue",linewidth=1.5,linestyle='--',label = 'Q = %.2f $\mathring{A}^{-1}$'%q[iq2])
plt.axvline(x=q[iq3],ymin=0,ymax=10000,c="green",linewidth=1.5,linestyle='--',label = 'Q = %.2f $\mathring{A}^{-1}$'%q[iq3])

#-------------------------------------------------
#----------------------------------------------
# --plot g(r)
ax2 = plt.subplot(1,3,3)    
    
for i in range(len(gr_plot)):
	color_index = float(i)/float(len(gr_plot))
	color = plt.cm.jet(color_index)
	plt.plot(r,gr_plot[i,:],color=color,label=i)

plt.xlabel('r / $\mathring{A}$', fontsize=20)
plt.ylabel('g$_{OO}$(r)', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.xlim((2,5.5))
plt.ylim((0,6.0))


#****************************************************************
# plot Intensity vs time for eHDA
plt.subplot(1,3,2)
plt.plot(T,Sq_plot[:,iq1], color='red', linestyle='solid', marker='o')
plt.plot(T,Sq_plot[:,iq2], color='blue', linestyle='solid', marker='o')
plt.plot(T,Sq_plot[:,iq3], color='green', linestyle='solid', marker='o')
plt.xlabel('T $(K)$', fontsize=20)
plt.ylabel('S$(Q=const.)$', fontsize=20)

plt.xlim([80,140])
plt.xticks(fontsize=20)
plt.ylim([0,2.75])
plt.yticks(fontsize=20)

plt.axvline(x=t[it1],ymin=0,ymax=10000,c="black",linewidth=1.5,linestyle='--',label = '117 K')
plt.text(81,2.35,'Q = 2.3 $\mathring{A}^{-1}$',fontsize=16)
plt.text(81,1.4,'Q = 2.1 $\mathring{A}^{-1}$',fontsize=16)
plt.text(81,0.2,'Q = 1.7 $\mathring{A}^{-1}$',fontsize=16)

plt.legend(frameon=False)

plt.tight_layout()

import click
if click.confirm('Do you want to save file?', default=True):
    plt.savefig(base_path+"VHDA-LDA_fast-heating.png")

plt.show()
# Out:
# Do you want to save file? [Y/n]: n
